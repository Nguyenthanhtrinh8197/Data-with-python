# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('house_price_dống-da.xlsx')
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1    Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3    Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4    Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# ..                                                 ...
# 995  Bán nhà mặt phố Yên Lãng, Đống Đa, 65m2, 5T, 1...
# 996  Bán nhà 5 tầng đep MP Yên Lãng giá rẻ, DT 60m2...
# 997  MẶT PHỐ XÃ ĐÀN - KINH DOANH ĐỈNH CAO - 6 TẦNG ...
# 998  Bán nhà mặt hồ Văn Chương, Đống Đa 33m2, 6 tần...
# 999  Bán nhà 5 tầng MP Chùa Bộc hạ giá sốc, tử 58,6...
#
#                                                address   area    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   address            1000 non-null   object
#  2   area               994 non-null    float64
#  3   price              944 non-null    float64
#  4   postDate           1000 non-null   datetime64[ns]
#  5   land_certificate   693 non-null    object
#  6   house_direction    44 non-null     object
#  7   balcony_direction  24 non-null     object
#  8   toilet             551 non-null    float64
#  9   bedroom            635 non-null    float64
#  10  floor              376 non-null    float64
#  11  type_of_land       1000 non-null   object
#  12  street_name        808 non-null    object
#  13  ward_name          802 non-null    object
#  14  district_name      1000 non-null   object
# ...

# %%
data.loc[:,'type_of_land'].unique()
# Out:
# array(['Bán nhà riêng\n ', 'Bán nhà mặt phố\n ', 'Tập thể, cư xá',
#        'Bán nhà riêng', 'Bán nhà mặt phố', 'Chung cư',
#        'Bất động sản khác', 'Bất động sản khác\n ', 'Đất thổ cư'],
#       dtype=object)

# %%
data.loc[:,'ward_name'].unique()
# Out:
# array(['Phường Trung Liệt', 'Phường Khâm Thiên', 'Phường Láng Thượng',
#        'Phường Quang Trung', 'Phường Láng Hạ', 'Phường Trung Phụng',
#        'Phường Kim Liên', 'Phường Nam Đồng', 'Phường Ô Chợ Dừa',
#        'Phường Hàng Bột', 'Phường Thịnh Quang', 'Phường Phương Mai',
#        'Phường Cát Linh', 'Phường Khương Thượng', 'Phường Quốc Tử Giám',
#        'Phường Trung Tự', 'Phường Văn Chương', nan, 'Phường Phương Liên',
#        'Phường Thổ Quan', 'Phường Ngã Tư Sở', 'Phường Văn Miếu'],
#       dtype=object)

# %%
cau2 = data[((data['type_of_land'] == 'Bán nhà riêng\n ')|(data['type_of_land'] == 'Bán nhà riêng'))
              & ((data['ward_name'] == 'Phường Trung Liệt') | (data['ward_name'] == 'Phường Khâm Thiên'))]
cau2
# Out:
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 33   Bán nhà siêu đẹp Khâm Thiên, Đống Đa 66m, 4 tầ...
# 43   Bán nhà phân lô, ô tô Thái Hà, Đống Đa 80m, 4 ...
# 244  Bán Nhà 41m2 x 5 tầng, view hồ, ô tô tránh, ki...
# ..                                                 ...
# 910  Bán nhà tặng nội thất Thái Hà - gần phố - nhà ...
# 931  4.5 tỷ! Bán nhà phố Trung Liệt – Đống Đa 45m, ...
# 940  Bán gấp nhà Thái Hà, Đống Đa, 35m, 5t, ô tô 20...
# 957  Bán nhà phân lô, ô tô tránh, Thái Hà, Đống Đa ...
# 975  Bán gấp nhà ngõ Đặng Tiến Đông, Trần Quang Diệ...
#
#                                                address   area    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   57.0   4200.0
# 33   Phố Chợ Khâm Thiên, Phường Văn Chương, Quận Đố...  256.0   6600.0
# ...

# %%
cau2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 975
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              85 non-null     object
#  1   address            85 non-null     object
#  2   area               85 non-null     float64
#  3   price              85 non-null     float64
#  4   postDate           85 non-null     datetime64[ns]
#  5   land_certificate   68 non-null     object
#  6   house_direction    5 non-null      object
#  7   balcony_direction  4 non-null      object
#  8   toilet             63 non-null     float64
#  9   bedroom            75 non-null     float64
#  10  floor              41 non-null     float64
#  11  type_of_land       85 non-null     object
#  12  street_name        85 non-null     object
#  13  ward_name          85 non-null     object
#  14  district_name      85 non-null     object
# ...

# %%
data.loc[:,'land_certificate'].unique()
# Out:
# array(['Sổ đỏ', nan], dtype=object)

# %%
data.loc[:,'bedroom'].unique()
# Out:
# array([ 6., nan,  8.,  5.,  3.,  4.,  2.,  1., 14.,  7., 10., 11.,  9.,
#        12., 22., 17., 13.])

# %%
nha3bedroom = data[(data['land_certificate'] == 'Sổ đỏ')
              & (data['bedroom'] >= 3)]
nha3bedroom
# Out:
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3    Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4    Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# 5    Bán gấp mặt phố Chùa Bộc, Đống Đa, thang máy, ...
# ..                                                 ...
# 989  Chính chủ cần bán gấp nhà khu Xã Đàn cực đẹp, ...
# 990  Bán nhà siêu đẹp Thịnh Quang, Đống Đa 47m,4 tầ...
# 991  Bán Nhà siêu đẹp Thịnh Quang, Đống Đa, 45m, 4 ...
# 995  Bán nhà mặt phố Yên Lãng, Đống Đa, 65m2, 5T, 1...
# 998  Bán nhà mặt hồ Văn Chương, Đống Đa 33m2, 6 tần...
#
#                                                address   area    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   57.0   4200.0
# 3    Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...   62.0  11000.0
# ...

# %%
cau3 = nha3bedroom.filter(['address', 'price','house_direction','balcony_direction'])
cau3
# Out:
#                                                address    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  14700.0
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   4200.0
# 3    Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  11000.0
# 4     Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  36000.0
# 5    Phố Chùa Bộc, Phường Quang Trung, Đống Đa, Hà Nội  13500.0
# ..                                                 ...      ...
# 989       Phố Xã Đàn, Phường Kim Liên, Đống Đa, Hà Nội   3900.0
# 990  Thịnh Quang, Phường Thịnh Quang, Quận Đống Đa,...   3700.0
# 991  Thịnh Quang, Phường Thịnh Quang, Quận Đống Đa,...   4100.0
# 995  Đường Yên Lãng, Phường Láng Hạ, Đống Đa, Hà...  17500.0
# 998  Hồ Văn Chương, Phường Văn Chương, Quận Đống Đa...   8100.0
#
#     house_direction balcony_direction
# 0               NaN               NaN
# 2               Nam               Nam
# 3              Đông          Đông-Nam
# 4               NaN               NaN
# ...

# %% [markdown]
# cau 4: Với mỗi loại nhà đất, tính trung bình cộng giá cũng như giá lớn nhất và giá nhỏ nhất.

# %%
data.loc[:,'type_of_land'].unique()
# Out:
# array(['Bán nhà riêng\n ', 'Bán nhà mặt phố\n ', 'Tập thể, cư xá',
#        'Bán nhà riêng', 'Bán nhà mặt phố', 'Chung cư',
#        'Bất động sản khác', 'Bất động sản khác\n ', 'Đất thổ cư'],
#       dtype=object)

# %%
nharieng = data[((data['type_of_land'] == 'Bán nhà riêng\n ')|(data['type_of_land'] == 'Bán nhà riêng'))]
cau4nharieng = nharieng.filter([ 'price'])
np.mean(cau4nharieng)
#np.max(cau4nharieng)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# price    8199.208214
# dtype: float64

# %%
np.max(cau4nharieng)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# price    120000.0
# dtype: float64

# %%
nhamatpho = data[((data['type_of_land'] == 'Bán nhà mặt phố\n ')|(data['type_of_land'] == 'Bán nhà mặt phố'))]
cau4nhamatpho = nhamatpho.filter([ 'price'])
np.mean(cau4nhamatpho)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# price    67493.187336
# dtype: float64

# %%
np.max(cau4nhamatpho)
# Out:
# price    3300000.0
# dtype: float64

# %%
np.min(cau4nhamatpho)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# price    4.5
# dtype: float64

# %%
BDSkhac = data[((data['type_of_land'] == 'Bất động sản khác')|(data['type_of_land'] == 'Bất động sản khác\n '))]
cau4BDSkhac = BDSkhac.filter([ 'price'])
np.mean(cau4BDSkhac)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# price    21094.736842
# dtype: float64

# %%
np.max(cau4BDSkhac)
# Out:
# price    52000.0
# dtype: float64

# %%
np.min(cau4BDSkhac)
# Out:
# price    30.0
# dtype: float64

# %%
tapthe = data[(data['type_of_land'] == 'Tập thể, cư xá')]
cau4tapthe = tapthe.filter([ 'price'])
np.mean(cau4tapthe)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# price    2094.637681
# dtype: float64

# %%
np.max(cau4tapthe)
# Out:
# price    8200.0
# dtype: float64

# %%
np.min(cau4tapthe)
# Out:
# price    450.0
# dtype: float64

# %%
datthocu = data[(data['type_of_land'] == 'Đất thổ cư')]
cau4datthocu = datthocu.filter([ 'price'])
np.mean(cau4datthocu)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# price    10585.0
# dtype: float64

# %%
np.max(cau4datthocu)
# Out:
# price    24500.0
# dtype: float64

# %%
np.min(cau4datthocu)
# Out:
# price    3680.0
# dtype: float64

# %% [markdown]
# cau 5. Tính trung bình cộng số phòng ngủ, số phòng vệ sinh, số tầng của mỗi phường.

# %%
data.loc[:,'ward_name'].unique()
# Out:
# array(['Phường Trung Liệt', 'Phường Khâm Thiên', 'Phường Láng Thượng',
#        'Phường Quang Trung', 'Phường Láng Hạ', 'Phường Trung Phụng',
#        'Phường Kim Liên', 'Phường Nam Đồng', 'Phường Ô Chợ Dừa',
#        'Phường Hàng Bột', 'Phường Thịnh Quang', 'Phường Phương Mai',
#        'Phường Cát Linh', 'Phường Khương Thượng', 'Phường Quốc Tử Giám',
#        'Phường Trung Tự', 'Phường Văn Chương', nan, 'Phường Phương Liên',
#        'Phường Thổ Quan', 'Phường Ngã Tư Sở', 'Phường Văn Miếu'],
#       dtype=object)

# %%
WnTL = data[(data['ward_name'] == 'Phường Khâm Thiên')]
cau5 = WnTL.filter(['bedroom','toilet','floor'])
cau5
# Out:
#      bedroom  toilet  floor
# 2        8.0     3.0    4.0
# 33       4.0     4.0    NaN
# 87       1.0     1.0    NaN
# 245      4.0     4.0    4.0
# 256      3.0     4.0    4.0
# 302      NaN     NaN    NaN
# 306      2.0     1.0    NaN
# 314      NaN     NaN    NaN
# 371      2.0     3.0    NaN
# 385      2.0     1.0    NaN
# 409      4.0     4.0    4.0
# 421      3.0     3.0    4.0
# 515      2.0     3.0    NaN
# 563      5.0     NaN    7.0
# 566     10.0     NaN    7.0
# 631      1.0     1.0    NaN
# 734      1.0     1.0    NaN
# 737      3.0     4.0    NaN
# 738      2.0     3.0    NaN
# 755      3.0     NaN    4.0
# 794      4.0     4.0    NaN
# 795      3.0     4.0    5.0
# 807      1.0     1.0    NaN
# 843      1.0     1.0    NaN
# 852      1.0     1.0    NaN
# 868      NaN     NaN    NaN
# 870     10.0    10.0    7.0
# 872      NaN     NaN    3.0
# 950      2.0     2.0    NaN
# 973      6.0     NaN    6.0

# %%
np.mean(cau5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# bedroom    3.384615
# toilet     2.863636
# floor      4.916667
# dtype: float64
